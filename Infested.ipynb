# %%
# Import dependencies
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)

# %%
#Read the data into a Pandas DataFrame
Infested_df = pd.read_csv('infestedwaters.csv',encoding="Latin-1")
Infested_df.head()
# Out:
#    W A T E R B O D Y N A M E  C O U N T Y O R C O U N T I E S  \
# 0                      Aaron                          Douglas
# 1                      Adley                       Otter Tail
# 2                      Agnes                          Douglas
# 3                  Alexander                         Morrison
# 4                  Alexander                         Morrison
#
#    L I S T E D F O R A Q U A T I C I N V A S I V E S P E C I E S  \
# 0                                                   zebra mussel
# 1                                                   zebra mussel
# 2                                                   zebra mussel
# 3                                          Eurasian watermilfoil
# 4                                                   zebra mussel
#
#     Y E A R L I S T E D A S I N F E S T E D  \
# 0                                      2020
# 1                                      2016
# 2                                      2022
# ...

# %%
Infested_df.columns
# Out:
# Index([' W A T E R B O D Y N A M E', ' C O U N T Y O R C O U N T I E S',
#        ' L I S T E D F O R A Q U A T I C I N V A S I V E S P E C I E S',
#        ' Y E A R L I S T E D A S I N F E S T E D',
#        ' Y E A R S P E C I E S W A S F I R S T C O N F I R M E D O R C O N N E C T E D',
#        ' D O W N U M B E R'],
#       dtype='object')

# %%
Rename_df = Infested_df.rename(columns={' W A T E R B O D Y N A M E': 'WaterBody',' C O U N T Y O R C O U N T I E S':'Counties',' L I S T E D F O R A Q U A T I C I N V A S I V E S P E C I E S':'List of Aquatic Invasive Species',' Y E A R L I S T E D A S I N F E S T E D':'Year Listed Infested'})
Rename_df
# Out:
#                                                                                WaterBody  \
# 0                                                                                  Aaron
# 1                                                                                  Adley
# 2                                                                                  Agnes
# 3                                                                              Alexander
# 4                                                                              Alexander
# ...                                                                                  ...
# 1601                                                                              Wright
# 1602                                                                              Zumbra
# 1603                                                                              Zumbro
# ...

# %%
Rename_df.drop(Rename_df.columns[[4,5]], axis=1, inplace=True)
Rename_df
# Out:
#                                                                                WaterBody  \
# 0                                                                                  Aaron
# 1                                                                                  Adley
# 2                                                                                  Agnes
# 3                                                                              Alexander
# 4                                                                              Alexander
# ...                                                                                  ...
# 1601                                                                              Wright
# 1602                                                                              Zumbra
# 1603                                                                              Zumbro
# ...

# %%
# Get a brief summary of the Infested_df DataFrame.
Rename_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606 entries, 0 to 1605
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   WaterBody                         1606 non-null   object
#  1   Counties                          1606 non-null   object
#  2   List of Aquatic Invasive Species  1606 non-null   object
#  3   Year Listed Infested              1606 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 50.3+ KB

# %%
# Finding missing values columnwise
Rename_df.isnull().sum()
# Out:
# WaterBody                           0
# Counties                            0
# List of Aquatic Invasive Species    0
# Year Listed Infested                0
# dtype: int64

# %%
Cleaned_df = Rename_df.to_csv('newinfestedwaters.csv')
Cleaned_df
